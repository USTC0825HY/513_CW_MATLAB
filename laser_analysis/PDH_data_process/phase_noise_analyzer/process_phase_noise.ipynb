# %%
import sys
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
plt.rcParams['font.sans-serif'] = ['Microsoft YaHei'] 

plt.rcParams['axes.unicode_minus'] = False 

plt.rcParams['mathtext.fontset'] = 'cm'

# Support launching from either the repository root or this notebook directory.
ANALYZER_DIR = Path('phase_noise_analyzer') if Path('phase_noise_analyzer').is_dir() else Path('.')
DATA_DIR = ANALYZER_DIR / 'data'
module_path = str(ANALYZER_DIR.resolve())
if module_path not in sys.path:
    sys.path.insert(0, module_path)

# %%
from fspn_phase_noise import parse_and_plot_fspn, parse_plot_and_export_fspn

# %%
# 定义文件路径
data_file = DATA_DIR / '1_free_2_falc_3_dian1_4_falc_power_amp_相噪.CSV'

# 定义Trace编号与名称的映射关系 (可根据需要增删)
trace_dict = {
    1: "自由运转",
    2: "使用FALC Pro锁定",
    3: "使用电1锁定",
    4: "使用FALC Pro锁定（PD输出加功放）"
}

ignore_list = [5, 6]

# 调用函数：指定目标Window为3，传入映射字典和跳过列表
# extracted_data = parse_and_plot_fspn(
#     filename=data_file, 
#     target_window=3,          # 你可以随时改为1或2来画其他窗口的数据
#     trace_mapping=trace_dict, 
#     skip_traces=ignore_list,
#     is_loglog=False,           # 如果你想要半对数图，可以改为False
#     append_title="-20260617"
# )
extracted_data = parse_plot_and_export_fspn(
    filename=data_file, 
    target_window=3, 
    trace_mapping=trace_dict, 
    skip_traces=ignore_list,
    is_loglog=False,
    append_title="-20260617"
)
# Out:
# 数据已成功导出至: data\1_free_2_falc_3_dian1_4_falc_power_amp_相噪_windows_3_trace1_2_3_4.csv

# %%
# 定义文件路径
data_file = DATA_DIR / 'JGQPDH.CSV'

# 定义Trace编号与名称的映射关系 (可根据需要增删)
trace_dict = {
    1: '技物所驱动板 锁定后',
    2: '频准激光器 锁定后',
    3: '技物所驱动板 开环',
    4: 'Ch4: Buffer',
    5: 'Ch5: Ground',
    6: '频准激光器 开环'
}

ignore_list = [4, 5]

# 调用函数：指定目标Window为3，传入映射字典和跳过列表
extracted_data = parse_plot_and_export_fspn(
    filename=data_file, 
    target_window=1,          # 你可以随时改为1或2来画其他窗口的数据
    trace_mapping=trace_dict, 
    skip_traces=ignore_list,
    append_title="-20260428"
)
# Out:
# 数据已成功导出至: data\JGQPDH_windows_1_trace1_2_3_6.csv

# %%
# 定义文件路径
data_file = DATA_DIR / 'File pkwk_014.CSV'

# 定义Trace编号与名称的映射关系 (可根据需要增删)
trace_dict = {
    1: '20260618 锁定',
    2: '20260618 锁定2',
    3: '开环',
    4: '20260618 锁定3'
}
ignore_list = []
# 调用函数：指定目标Window为3，传入映射字典和跳过列表
extracted_data = parse_plot_and_export_fspn(
    filename=data_file, 
    target_window=1,          # 你可以随时改为1或2来画其他窗口的数据
    trace_mapping=trace_dict, 
    skip_traces=ignore_list,
    append_title="-20260428",
    xlim=(5e-1, 3e6)
)
# Out:
# C:\Users\WangYu\USTCDrive\USL_DLOCK\3.Code\PDH_data_process\phase_noise_analyzer\fspn_phase_noise.py:259: RuntimeWarning: File pkwk_014.CSV, Window 1, Trace 1: discarding 400 non-positive values declared as Hz/sqrt(Hz)
#   parsed = parse_fspn_window(filename, target_window, skip_traces)
# C:\Users\WangYu\USTCDrive\USL_DLOCK\3.Code\PDH_data_process\phase_noise_analyzer\fspn_phase_noise.py:259: RuntimeWarning: File pkwk_014.CSV, Window 1, Trace 2: discarding 400 non-positive values declared as Hz/sqrt(Hz)
#   parsed = parse_fspn_window(filename, target_window, skip_traces)
# C:\Users\WangYu\USTCDrive\USL_DLOCK\3.Code\PDH_data_process\phase_noise_analyzer\fspn_phase_noise.py:259: RuntimeWarning: File pkwk_014.CSV, Window 1, Trace 3: discarding 400 non-positive values declared as Hz/sqrt(Hz)
#   parsed = parse_fspn_window(filename, target_window, skip_traces)
# ...

# %%
# 定义文件路径
data_file = DATA_DIR / '20260624修改地检后相噪仪数据.CSV'

# 定义Trace编号与名称的映射关系 (可根据需要增删)
trace_dict = {
    1: '20260624 锁定',
    2: '20260624 开环',
    3: '20260624 锁定2'
}
ignore_list = []
# 调用函数：指定目标Window为3，传入映射字典和跳过列表
extracted_data = parse_plot_and_export_fspn(
    filename=data_file, 
    target_window=1,          # 你可以随时改为1或2来画其他窗口的数据
    trace_mapping=trace_dict, 
    skip_traces=ignore_list,
    append_title="-20260624"

)
# Out:
# C:\Users\WangYu\USTCDrive\USL_DLOCK\3.Code\PDH_data_process\phase_noise_analyzer\fspn_phase_noise.py:259: RuntimeWarning: 20260624修改地检后相噪仪数据.CSV, Window 1, Trace 1: discarding 349 non-positive values declared as Hz/sqrt(Hz)
#   parsed = parse_fspn_window(filename, target_window, skip_traces)
# C:\Users\WangYu\USTCDrive\USL_DLOCK\3.Code\PDH_data_process\phase_noise_analyzer\fspn_phase_noise.py:259: RuntimeWarning: 20260624修改地检后相噪仪数据.CSV, Window 1, Trace 2: discarding 349 non-positive values declared as Hz/sqrt(Hz)
#   parsed = parse_fspn_window(filename, target_window, skip_traces)
# C:\Users\WangYu\USTCDrive\USL_DLOCK\3.Code\PDH_data_process\phase_noise_analyzer\fspn_phase_noise.py:259: RuntimeWarning: 20260624修改地检后相噪仪数据.CSV, Window 1, Trace 3: discarding 349 non-positive values declared as Hz/sqrt(Hz)
#   parsed = parse_fspn_window(filename, target_window, skip_traces)
# 数据已成功导出至: data\20260624修改地检后相噪仪数据_windows_1_trace1_2_3.csv

# %%
# 定义文件路径
data_file = DATA_DIR / '模数_开环_数字_模数混合.CSV'

# 定义Trace编号与名称的映射关系 (可根据需要增删)
trace_dict = {
    1: '20260624 模拟',
    2: '20260624 开环',
    3: '20260624 数字',
    4: '20260624 模数混合'
}
ignore_list = []
# 调用函数：指定目标Window为3，传入映射字典和跳过列表
extracted_data = parse_plot_and_export_fspn(
    filename=data_file, 
    target_window=1,          # 你可以随时改为1或2来画其他窗口的数据
    trace_mapping=trace_dict, 
    skip_traces=ignore_list,
    append_title="-20260624"

)
# Out:
# 数据已成功导出至: data\模数_开环_数字_模数混合_windows_1_trace1_2_3_4.csv

# %%
# 定义文件路径
data_file = DATA_DIR / '模拟_开环_数字_模数混合_模拟.CSV'

# 定义Trace编号与名称的映射关系 (可根据需要增删)
trace_dict = {
    1: '20260624 模拟',
    2: '20260624 开环',
    3: '20260624 数字',
    4: '20260624 模数混合',
    5: '20260624 模拟2'
}
ignore_list = []
# 调用函数：指定目标Window为3，传入映射字典和跳过列表
extracted_data = parse_plot_and_export_fspn(
    filename=data_file, 
    target_window=1,          # 你可以随时改为1或2来画其他窗口的数据
    trace_mapping=trace_dict, 
    skip_traces=ignore_list,
    append_title="-20260624"

)
# Out:
# 数据已成功导出至: data\模拟_开环_数字_模数混合_模拟_windows_1_trace1_2_3_4_5.csv

# %%
# 定义文件路径
data_file = DATA_DIR / '20260625晚上几组锁定参数对比.CSV'

# 定义Trace编号与名称的映射关系 (可根据需要增删)
trace_dict = {
    1: '20260624 ',
    2: '20260624 开环',
    3: '20260624 数字',
    4: '20260624 模数混合',
    5: '20260624 模拟2'
}
ignore_list = []
# 调用函数：指定目标Window为3，传入映射字典和跳过列表
extracted_data = parse_plot_and_export_fspn(
    filename=data_file, 
    target_window=1,          # 你可以随时改为1或2来画其他窗口的数据
    trace_mapping=trace_dict, 
    skip_traces=ignore_list,
    append_title="-20260624"

)
# Out:
# 数据已成功导出至: data\20260625晚上几组锁定参数对比_windows_1_trace1_2_3_4_5_6.csv

# %%
# 定义文件路径
data_file = DATA_DIR / '20260626关制冷机水冷机2.CSV'

# 定义Trace编号与名称的映射关系 (可根据需要增删)
trace_dict = {
    1: '20260626 关水冷 关制冷',
    2: '20260626 全开',
    3: '20260626 关水冷 开制冷',
    4: '20260626 开水冷 关制冷'
}
ignore_list = []
# 调用函数：指定目标Window为3，传入映射字典和跳过列表
extracted_data = parse_plot_and_export_fspn(
    filename=data_file, 
    target_window=1,          # 你可以随时改为1或2来画其他窗口的数据
    trace_mapping=trace_dict, 
    skip_traces=ignore_list,
    append_title="-20260624",
    is_loglog=True

)
# Out:
# 数据已成功导出至: data\20260626关制冷机水冷机2_windows_1_trace1_2_3_4.csv

# %%
# 定义文件路径
data_file = DATA_DIR / '20260626关制冷机水冷机3.CSV'

# 定义Trace编号与名称的映射关系 (可根据需要增删)
trace_dict = {
    1: '20260626 技物所激光器',
    2: '20260626 全开',
    3: '20260626 关水冷 开制冷',
    4: '20260626 开水冷 关制冷',
    5: '20260626 关水冷 关制冷'
}
ignore_list = [1]
# 调用函数：指定目标Window为3，传入映射字典和跳过列表
extracted_data = parse_plot_and_export_fspn(
    filename=data_file, 
    target_window=1,          # 你可以随时改为1或2来画其他窗口的数据
    trace_mapping=trace_dict, 
    skip_traces=ignore_list,
    append_title="-20260624",
    is_loglog=True

)
# Out:
# 数据已成功导出至: .\20260626关制冷机水冷机3_windows_1_trace2345.csv

# %%
# 定义文件路径
data_file = r'c:\Users\WangYu\USTCDrive\USL_DLOCK\1.Data\杨正光上传\环外噪声\20260701\bode100_扫描配置\三种配置下的伺拍频相噪.CSV'

# 定义Trace编号与名称的映射关系 (可根据需要增删)
trace_dict = {
    1: '20260702 配置1',
    2: '20260702 配置3',
    3: '20260702 配置2',
    4: '20260702 配置3-2',
    5: '20260702 配置1',
    6: '20260702 开环',
}
ignore_list = []
# 调用函数：指定目标Window为3，传入映射字典和跳过列表
extracted_data = parse_plot_and_export_fspn(
    filename=data_file, 
    target_window=1,          # 你可以随时改为1或2来画其他窗口的数据
    trace_mapping=trace_dict, 
    skip_traces=ignore_list,
    append_title="-20260624",
    is_loglog=True

)
# Out:
# 数据已成功导出至: c:\Users\WangYu\USTCDrive\USL_DLOCK\1.Data\杨正光上传\环外噪声\20260701\bode100_扫描配置\三种配置下的伺拍频相噪_windows_1_trace123456.csv

# %%
# 定义文件路径
## 模数混合测试
data_file = r'c:\Users\WangYu\USTCDrive\USL_DLOCK\1.Data\杨正光上传\环外噪声\20260702\模数混合-带宽\频率噪声.CSV'

# 定义Trace编号与名称的映射关系 (可根据需要增删)
trace_dict = {
    1: '数字慢+模拟快(gain=2.15×1.31)',
    2: '数字快(gain=9)+数字慢+模拟快(gain=2.15×1.31)',
    3: '纯数字：数字快(gain=12)+数字慢',
    4: '数字快(gain=3)+数字慢+模拟快(gain=2.15×1.168)',
    5: '数字快(gain=9)+数字慢+模拟快(gain=2.15×1.168)',
    6: '数字快(gain=6)+数字慢+模拟快(gain=2.15×1.168)',
}
ignore_list = []
# 调用函数：指定目标Window为3，传入映射字典和跳过列表
extracted_data = parse_plot_and_export_fspn(
    filename=data_file, 
    target_window=1,          # 你可以随时改为1或2来画其他窗口的数据
    trace_mapping=trace_dict, 
    skip_traces=ignore_list,
    append_title="-20260624",
    is_loglog=True

)
# Out:
# 数据已成功导出至: c:\Users\WangYu\USTCDrive\USL_DLOCK\1.Data\杨正光上传\环外噪声\20260702\模数混合-带宽\频率噪声_windows_1_trace123456.csv

# %%
# 定义文件路径
## 模数混合测试
data_file = r'C:\Users\WangYu\USTCDrive\USL_DLOCK\3.Code\PDH_data_process\phase_noise_analyzer\data\20260715技物所激光器驱动对比.CSV'

# 定义Trace编号与名称的映射关系 (可根据需要增删)
trace_dict = {
    1: '频准锁定（未测完）',
    2: 'Si3未拍频（接错了：当时激光器驱动板未上电）',
    3: '技物所驱动自由运转',
    4: '技物所驱动锁定（频准电控-配置1）',
    5: '技物所驱动锁定（频准电控-配置2）',
    6: '频准激光器自由运转',
}
ignore_list = [1,2]
# 调用函数：指定目标Window为3，传入映射字典和跳过列表
extracted_data = parse_plot_and_export_fspn(
    filename=data_file, 
    target_window=1,          # 你可以随时改为1或2来画其他窗口的数据
    trace_mapping=trace_dict, 
    skip_traces=ignore_list,
    append_title="-20260624",
    is_loglog=True

)
# Out:
# 数据已成功导出至: C:\Users\WangYu\USTCDrive\USL_DLOCK\3.Code\PDH_data_process\phase_noise_analyzer\data\20260715技物所激光器驱动对比_windows_1_trace3_4_5_6.csv

# %%
# 定义文件路径
## 模数混合测试
data_file = r'C:\Users\WangYu\USTCDrive\USL_DLOCK\3.Code\PDH_data_process\phase_noise_analyzer\data\20260715技物所激光器驱动对比-补测频准激光器锁定.csv'

# 定义Trace编号与名称的映射关系 (可根据需要增删)
trace_dict = {
    1: '频准激光器锁定'
}
ignore_list = []
# 调用函数：指定目标Window为3，传入映射字典和跳过列表
extracted_data = parse_plot_and_export_fspn(
    filename=data_file, 
    target_window=1,          # 你可以随时改为1或2来画其他窗口的数据
    trace_mapping=trace_dict, 
    skip_traces=ignore_list,
    append_title="-20260624",
    is_loglog=True

)
# Out:
# 数据已成功导出至: C:\Users\WangYu\USTCDrive\USL_DLOCK\3.Code\PDH_data_process\phase_noise_analyzer\data\20260715技物所激光器驱动对比-补测频准激光器锁定_windows_1_trace1.csv
